# %%
import time
import pandas as pd
import requests

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


# Headers for API Request
header_data  = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# constants for season type
regular_season = 'Regular Season'
playoffs = 'Playoffs'

# build play by play url
def play_by_play_url(game_id):
    return "https://stats.nba.com/stats/playbyplayv2/?gameId={0}&startPeriod=0&endPeriod=14".format(game_id)

# build game log url
def game_log_url(season, season_type):
    return "http://stats.nba.com/stats/leaguegamelog/?leagueId=00&season={}&seasonType={}&playerOrTeam=T&counter=0&sorter=PTS&direction=ASC&dateFrom=&dateTo=".format(season, season_type)

# extracts pbp data from api response
def extract_data(url):
    print(url)
    r = requests.get(url, headers=header_data)
    resp = r.json()
    results = resp['resultSets'][0]
    headers = results['headers']
    rows = results['rowSet']
    frame = pd.DataFrame(rows)
    frame.columns = headers
    return frame


###
### Download and Save Play by Play Data
###
def download_pbp(game_id):
    play_by_play = extract_data(play_by_play_url(game_id))

    play_by_play.to_csv("data/{}_pbp.csv".format(game_id), index=False)

# # Set the season and season typ
# season = '2021-22'
# season_type = regular_season

# # Download the league game log
# schedule = extract_data(game_log_url(season, season_type))

# # Save the game log in case you want it for future reference
# schedule.to_csv('data/schedule_{}_{}.csv'.format(season, season_type), index=False)
# # Get all of the unique game ids
# game_ids = schedule['GAME_ID'].unique()
# game_ids.sort()

# # For each game id, download the play by play then sleep for .75 seconds so that we don't hit the stats nba rate limit
# # for id in game_ids[:500]:
# #     download_pbp(id)
# #     time.sleep(.75)
# Out:
# http://stats.nba.com/stats/leaguegamelog/?leagueId=00&season=2021-22&seasonType=Regular Season&playerOrTeam=T&counter=0&sorter=PTS&direction=ASC&dateFrom=&dateTo=
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100001&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100002&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100003&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100004&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100005&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100006&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100007&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100008&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100009&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100010&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100011&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100012&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100013&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100014&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100015&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100016&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100017&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100018&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100019&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100020&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100021&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100022&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100023&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100024&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100025&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100026&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100027&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100028&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100029&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100030&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100031&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100032&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100033&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100034&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100035&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100036&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100037&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100038&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100039&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100040&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100041&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100042&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100043&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100044&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100045&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100046&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100047&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100048&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100049&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100050&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100051&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100052&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100053&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100054&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100055&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100056&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100057&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100058&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100059&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100060&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100061&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100062&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100063&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100064&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100065&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100066&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100067&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100068&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100069&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100070&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100071&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100072&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100073&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100074&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100075&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100076&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100077&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100078&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100079&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100080&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100081&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100082&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100083&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100084&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100085&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100086&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100087&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100088&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100089&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100090&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100091&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100092&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100093&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100094&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100095&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100096&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100097&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100098&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100099&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100100&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100101&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100102&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100103&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100104&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100105&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100106&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100107&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100108&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100109&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100110&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100111&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100112&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100113&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100114&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100115&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100116&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100117&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100118&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100119&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100120&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100121&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100122&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100123&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100124&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100125&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100126&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100127&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100128&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100129&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100130&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100131&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100132&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100133&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100134&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100135&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100136&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100137&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100138&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100139&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100140&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100141&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100142&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100143&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100144&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100145&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100146&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100147&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100148&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100149&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100150&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100151&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100152&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100153&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100154&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100155&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100156&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100157&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100158&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100159&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100160&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100161&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100162&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100163&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100164&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100165&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100166&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100167&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100168&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100169&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100170&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100171&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100172&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100173&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100174&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100175&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100176&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100177&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100178&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100179&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100180&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100181&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100182&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100183&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100184&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100185&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100186&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100187&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100188&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100189&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100190&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100191&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100192&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100193&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100194&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100195&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100196&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100197&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100198&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100199&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022100200&startPeriod=0&endPeriod=14
# https://stats.nba.com/stats/playbyplayv2/?gameId=0022
        subs = df[[tag, 'PERIOD', 'EVENTNUM']]
        subs['SUB'] = tag
        subs.columns = ['PLAYER_ID', 'PERIOD', 'EVENTNUM', 'SUB']
        return subs


    def frame_to_row(df):
        team1 = df['TEAM_ID'].unique()[0]
        team2 = df['TEAM_ID'].unique()[1]
        players1 = df[df['TEAM_ID'] == team1]['PLAYER_ID'].tolist()
        players1.sort()
        players2 = df[df['TEAM_ID'] == team2]['PLAYER_ID'].tolist()
        players2.sort()

        lst = [team1]
        lst.append(players1)
        lst.append(team2)
        lst.append(players2)


        return lst


    # extracts data from api response
    def extract_data(url):
        print(url)
        r = requests.get(url, headers=header_data)
        resp = r.json()
        results = resp['resultSets'][0]
        headers = results['headers']
        rows = results['rowSet']
        frame = pd.DataFrame(rows)
        frame.columns = headers
        return frame


    play_by_play = pd.read_csv(('data/{}_pbp.csv'.format(game_id)))

    substitutionsOnly = play_by_play[(play_by_play['EVENTMSGTYPE'] == 8)][['PERIOD','EVENTNUM','PLAYER1_ID','PLAYER2_ID']]
    substitutionsOnly.columns = ['PERIOD', 'EVENTNUM', 'OUT', 'IN']

    subs_in = split_subs(substitutionsOnly, 'IN')
    subs_out = split_subs(substitutionsOnly, 'OUT')

    full_subs = pd.concat([subs_out, subs_in], axis=0).reset_index()[['PLAYER_ID', 'PERIOD', 'EVENTNUM', 'SUB']]
    first_event_of_period = full_subs.loc[full_subs.groupby(by=['PERIOD', 'PLAYER_ID'])['EVENTNUM'].idxmin()]
    players_subbed_in_at_each_period = first_event_of_period[first_event_of_period['SUB'] == 'IN'][
        ['PLAYER_ID', 'PERIOD', 'SUB']]

    
    periods = players_subbed_in_at_each_period['PERIOD'].drop_duplicates().values.tolist()

    if game_id == "0022100291":
        periods = [1,2,3,4,5,6,7]
    
    rows = []
    for period in periods:
        low = calculate_time_at_period(period) + 5
        high = calculate_time_at_period(period + 1) - 5
        boxscore = advanced_boxscore_url(game_id, low, high)
        boxscore_players = extract_data(boxscore)[['PLAYER_NAME', 'PLAYER_ID', 'TEAM_ID']]
        boxscore_players['PERIOD'] = period

        players_subbed_in_at_period = players_subbed_in_at_each_period[players_subbed_in_at_each_period['PERIOD'] == period]

        joined_players = pd.merge(boxscore_players, players_subbed_in_at_period, on=['PLAYER_ID', 'PERIOD'], how='left')
        joined_players = joined_players[pd.isnull(joined_players['SUB'])][['PLAYER_NAME', 'PLAYER_ID', 'TEAM_ID', 'PERIOD']]
        row = frame_to_row(joined_players)
        row.append(period)
        rows.append(row)
        time.sleep(.25)
    print(rows)
    players_on_court_at_start_of_period = pd.DataFrame(rows)
    cols = ['TEAM_ID_1', 'TEAM_1_PLAYERS', 'TEAM_ID_2', 'TEAM_2_PLAYERS', 'PERIOD']
    players_on_court_at_start_of_period.columns = cols
    players_on_court_at_start_of_period.to_csv("data/{}_players_at_period.csv".format(game_id), index=False)
# Out:
# https://stats.nba.com/stats/boxscoretraditionalv2/?gameId=0022100291&startPeriod=0&endPeriod=14&startRange=5&endRange=7195&rangeType=2
# https://stats.nba.com/stats/boxscoretraditionalv2/?gameId=0022100291&startPeriod=0&endPeriod=14&startRange=7205&endRange=14395&rangeType=2
# https://stats.nba.com/stats/boxscoretraditionalv2/?gameId=0022100291&startPeriod=0&endPeriod=14&startRange=14405&endRange=21595&rangeType=2
# https://stats.nba.com/stats/boxscoretraditionalv2/?gameId=0022100291&startPeriod=0&endPeriod=14&startRange=21605&endRange=28795&rangeType=2
# https://stats.nba.com/stats/boxscoretraditionalv2/?gameId=0022100291&startPeriod=0&endPeriod=14&startRange=28805&endRange=31795&rangeType=2
# https://stats.nba.com/stats/boxscoretraditionalv2/?gameId=0022100291&startPeriod=0&endPeriod=14&startRange=31805&endRange=34795&rangeType=2
# https://stats.nba.com/stats/boxscoretraditionalv2/?gameId=0022100291&startPeriod=0&endPeriod=14&startRange=34805&endRange=37795&rangeType=2
# [[1610612758, [203090, 203458, 1628368, 1629002, 1630169], 1610612747, [2544, 201566, 201599, 202340, 203076], 1], [1610612758, [203090, 1627745, 1628963, 1630169, 1630558], 1610612747, [2544, 2546, 2730, 201566, 201961], 2], [1610612758, [203458, 1628368, 1629002, 1629056, 1630169], 1610612747, [2544, 201566, 201599, 202340, 203076], 3], [1610612758, [203458, 1627741, 1628963, 1630169, 1630558], 1610612747, [2544, 2546, 2730, 201566, 1628370], 4], [1610612758, [203458, 1628368, 1628963, 1629056, 1630169], 1610612747, [2544, 2546, 201566, 203076, 1628370], 5], [1610612758, [203458, 1627741, 1628368, 1628963, 1630169], 1610612747, [2544, 2546, 201566, 203076, 1628370], 6], [1610612758, [203458, 1627741, 1628368, 1628963, 1630169], 1610612747, [2544, 2546, 201566, 203076, 1628370], 7]]

# %%
# Import os for relative pathing to data
import os
import pandas as pd
# Import our play by play utils file
from play_by_play_utils import *

# Set columns and width for easier printing
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

parsed_possessions = []

for game_id in game_ids[:500]:
    if game_id not in ["0022100019", "0022100107", "0022100158", 
                       "0022100182", "0022100225", "0022100239",
                      "0022100251", "0022100275", "0022100493"]:
        dirname = ""

        # generate file path for play by play and players on court data
        input_play_by_play = os.path.join(dirname, './data/{}_pbp.csv'.format(game_id))
        input_players_on_court = os.path.join(dirname, './data/{}_players_at_period.csv'.format(game_id))
        output_path = os.path.join(dirname, './data/{}_possessions.csv'.format(game_id))


        # Read in play by play and fill null description columsn with empty string
        play_by_play = pd.read_csv(input_play_by_play, index_col=False)
        play_by_play[home_description] = play_by_play[home_description].fillna("")
        play_by_play[neutral_description] = play_by_play[home_description].fillna("")
        play_by_play[away_description] = play_by_play[away_description].fillna("")


        # We will need to know the game clock at each event later on. Let's take the game clock string (7:34) and convert it into seconds elapsed
        def parse_time_elapsed(time_str, period):
            # Maximum minutes in a period is 12 unless overtime
            max_minutes = 12 if period < 5 else 5
            # Split string on :
            [minutes, sec] = time_str.split(':')
            # extract minutes and seconds
            minutes = int(minutes)
            sec = int(sec)

            # 7:34 (4 minutes 26 seconds have passed) -> 12 - 7 -> 5, need to subtract an extra minute.
            min_elapsed = max_minutes - minutes - 1
            sec_elapsed = 60 - sec

            return (min_elapsed * 60) + sec_elapsed

        # We will also need to calculate the total time elapsed, not just the time elapsed in the period
        def calculate_time_elapsed(row):
            # Caclulate time elapsed in the period
            time_in_period = calculate_time_elapsed_period(row)
            period = row[period_column]
            # Calculate total time elapsed up to the start of the current period
            if period > 4:
                return (12 * 60 * 4) + ((period - 5) * 5 * 60) + time_in_period
            else:
                return ((period - 1) * 12 * 60) + time_in_period

        # method for calculating time elapsed in a period from a play by play event row
        def calculate_time_elapsed_period(row):
            return parse_time_elapsed(row[game_clock], row[period_column])

        # Apply the methods for calculating time to add the columns to the dataframe
        play_by_play[time_elapsed] = play_by_play.apply(calculate_time_elapsed, axis=1)
        play_by_play[time_elapsed_period] = play_by_play.apply(calculate_time_elapsed_period, axis=1)


        # Read the players at the start of each period
        players_at_start_of_period = pd.read_csv(input_players_on_court)

        # Players at the start of each period are stored as an string in the dataframe column
        # We need to parse out that string into an array of player Ids
        def split_row(list_str):
            return [x.replace('[', '').replace(']', '').strip() for x in list_str.split(',')]

        # We need to keep track of substitutions as they happen. To do this we will maintain a map of players on the court at a given moment
        # It will be structured as period -> team_id -> players array
        sub_map = {}
        # Pre-populate the map with the players at the start of each period
        for row in players_at_start_of_period.iterrows():
            sub_map[row[1][period_column]] = {row[1]['TEAM_ID_1']: split_row(row[1]['TEAM_1_PLAYERS']),
                                         row[1]['TEAM_ID_2']: split_row(row[1]['TEAM_2_PLAYERS'])}

        # players on the court need to be updated after every substitution
        def update_subs(row):
            period = row[period_column]
            # If the event is a substitution we need to sub out the players on the court
            if is_substitution(row):
                team_id = row[player1_team_id]
                player_in = str(row[player2_id])
                player_out = str(row[player1_id])
                players = sub_map[period][team_id]
                players_index = players.index(player_out)
                players[players_index] = player_in
                players.sort()
                sub_map[period][team_id] = players
            # Once we have subbed the players in/out in our sub map we can add those players to the current event row so that
            # Each event has all of the players involved with the event included
            for i, k in enumerate(sub_map[period].keys()):
                row['TEAM{}_ID'.format(i + 1)] = k
                row['TEAM{}_PLAYER1'.format(i + 1)] = sub_map[period][k][0]
                row['TEAM{}_PLAYER2'.format(i + 1)] = sub_map[period][k][1]
                row['TEAM{}_PLAYER3'.format(i + 1)] = sub_map[period][k][2]
                row['TEAM{}_PLAYER4'.format(i + 1)] = sub_map[period][k][3]
                row['TEAM{}_PLAYER5'.format(i + 1)] = sub_map[period][k][4]
        print(game_id)

        """
        What ends a possession?


        1. Made Shot (Need to account for And-1s)
        2. Defensive Rebound
        3. Turnover
        4. Last made free throw  (Ignore FT 1 of 1 on away from play fouls with no made shot)
        """
        def is_end_of_possession(ind, row, rows):
            return is_turnover(row) or (is_last_free_throw_made(ind, row, rows)) or is_defensive_rebound(ind, row, rows) or \
                   is_make_and_not_and_1(ind, row, rows) or is_end_of_period(row)


        # The main function of our tutorial, the method to group events by possession
        def parse_possessions(rows):
            # we will have a list of possessions and each possession will be a list of events
            possessions = []
            current_posession = []
            for ind, row in rows:
                # update our subs
                update_subs(row)
                # No need to include subs or end of period events in our possession list
                if not is_substitution(row) and not is_end_of_period(row):
                    current_posession.append(row)
                # if the current event is the last event of a possession, add the current possession to our list of possessions
                # and start a new possession
                if is_end_of_possession(ind, row, rows):
                    # No need to add empty end of period possessions
                    if len(current_posession) > 0:
                        possessions.append(current_posession)
                    current_posession = []
            return possessions




        # convert dataframe into a list of rows. I know there is a better way to do this,
        # but this is the first thing I thought of.
        pbp_rows = list(play_by_play.iterrows())
        possessions = parse_possessions(pbp_rows)


        # Print out the first couple of possessions so that you can see how the parser split them.


        # We need to count up each teams points from a possession
        def count_points(possession):
            # points will be a map where the key is the team id and the value is the number of points scored in that possesion
            points = {}
            for p in possession:
                if is_made_shot(p) or (not is_miss(p) and is_free_throw(p)):
                    if p[player1_team_id] in points:
                        points[p[player1_team_id]] += extract_points(p)
                    else:
                        points[p[player1_team_id]] = extract_points(p)
            return points

        # We need to count up each teams turnovers
        def count_turnovers(possession):
            # turnovers will be a map where the key is the team id and the value is the number of 
            # turnovers scored in that possesion
            team_turnovers = {}
            for p in possession:
                if is_team_turnover(p):
                    if p[player1_team_id] in team_turnovers:
                        team_turnovers[p[player1_team_id]] += 1
                    else:
                        team_turnovers[p[player1_team_id]] = 1
            return team_turnovers

        # We need to know how many points each shot is worth:
        def extract_points(p):
            if is_free_throw(p) and not is_miss(p):
                return 1
            elif is_made_shot(p) and is_three(p):
                return 3
            elif is_made_shot(p) and not is_three(p):
                return 2
            else:
                return 0

        # We need to determine which team has possession of the ball based on how the possession ended

        # If the possession ended with a made shot or free throw then we can determine that the team of the player
        # who made the shot was the team with possession of the ball
        #
        # If the possession ended with a rebound then we can determine that the team that did not get the rebound is
        # the team that had possession of the ball (ORBDs do not end possessions)
        #
        # If the possession ended with a turnover then we can determine that the team that committed the turnover is
        # the team that had possession of the ball
        #
        # If the possession ended due to the end of a period, we probably have some other random event as the last event
        # We can assume that the team1 id of that event is the team with the ball
        # improvements can be made by handling each event type individually
        def determine_possession_team(p, team1, team2):
            if is_made_shot(p) or is_free_throw(p):
                return str(int(p[player1_team_id]))
            elif is_rebound(p):
                if is_team_rebound(p):
                    if p[player1_id] == team1:
                        return team2
                    else:
                        return team1
                else:
                    if p[player1_team_id] == team1:
                        return team2
                    else:
                        return team1
            elif is_turnover(p):
                if is_team_turnover(p):
                    return str(int(p[player1_id]))
                else:
                    return str(int(p[player1_team_id]))
            else:
                if math.isnan(p[player1_team_id]):
                    return str(int(p[player1_id]))
                else:
                    return str(int(p[player1_team_id]))


        # Parse out the list of events in a possession into a single possession object
        # for this tutorial we will only include the players on the court, the game id, period, start and end time of possesion,
        # points scored by each team, and which team was on offense during the possession.
        def parse_possession(possession):
            times_of_events = [p[time_elapsed] for p in possession]
            possession_start = min(times_of_events)
            possession_end = max(times_of_events)
            points = count_points(possession)
            turnovers = count_turnovers(possession)
            game_id = possession[0]['GAME_ID']
            period = possession[0][period_column]
            team1_id = possession[0]['TEAM1_ID']
            team1_player1 = possession[0]['TEAM1_PLAYER1']
            team1_player2 = possession[0]['TEAM1_PLAYER2']
            team1_player3 = possession[0]['TEAM1_PLAYER3']
            team1_player4 = possession[0]['TEAM1_PLAYER4']
            team1_player5 = possession[0]['TEAM1_PLAYER5']
            team1_points = points[team1_id] if team1_id in points else 0

            team2_id = possession[0]['TEAM2_ID']
            team2_player1 = possession[0]['TEAM2_PLAYER1']
            team2_player2 = possession[0]['TEAM2_PLAYER2']
            team2_player3 = possession[0]['TEAM2_PLAYER3']
            team2_player4 = possession[0]['TEAM2_PLAYER4']
            team2_player5 = possession[0]['TEAM2_PLAYER5']
            team2_points = points[team2_id] if team2_id in points else 0

            possession_team = determine_possession_team(possession[-1], team1_id, team2_id)

            return {
                'team1_id': str(team1_id),
                'team1_player1': str(team1_player1),
                'team1_player2': str(team1_player2),
                'team1_player3': str(team1_player3),
                'team1_player4': str(team1_player4),
                'team1_player5': str(team1_player5),
                'team2_id': str(team2_id),
                'team2_player1': str(team2_player1),
                'team2_player2': str(team2_player2),
                'team2_player3': str(team2_player3),
                'team2_player4': str(team2_player4),
                'team2_player5': str(team2_player5),
                'game_id': str(game_id),
                'period': period,
                'possession_start': possession_start,
                'possession_end': possession_end,
                'team1_points': team1_points,
                'team2_points': team2_points,
                'possession_team': str(possession_team),
                'turnover': turnovers
            }

        # Build a list of parsed possession objects
#         parsed_possessions = []
        for possession in possessions:
            parsed_possessions.append(parse_possession(possession))

        # Build a dataframe from the list of parsed possession
df = pd.DataFrame(parsed_possessions)

df.to_csv(output_path, index=False)
# Out:
# 0022100001
# 0022100002
# 0022100003
# 0022100004
# 0022100005
# 0022100006
# 0022100007
# 0022100008
# 0022100009
# 0022100010
# 0022100011
# 0022100012
# 0022100013
# 0022100014
# 0022100015
# 0022100016
# 0022100017
# 0022100018
# 0022100020
# 0022100021
# 0022100022
# 0022100023
# 0022100024
# 0022100025
# 0022100026
# 0022100027
# 0022100028
# 0022100029
# 0022100030
# 0022100031
# 0022100032
# 0022100033
# 0022100034
# 0022100035
# 0022100036
# 0022100037
# 0022100038
# 0022100039
# 0022100040
# 0022100041
# 0022100042
# 0022100043
# 0022100044
# 0022100045
# 0022100046
# 0022100047
# 0022100048
# 0022100049
# 0022100050
# 0022100051
# 0022100052
# 0022100053
# 0022100054
# 0022100055
# 0022100056
# 0022100057
# 0022100058
# 0022100059
# 0022100060
# 0022100061
# 0022100062
# 0022100063
# 0022100064
# 0022100065
# 0022100066
# 0022100067
# 0022100068
# 0022100069
# 0022100070
# 0022100071
# 0022100072
# 0022100073
# 0022100074
# 0022100075
# 0022100076
# 0022100077
# 0022100078
# 0022100079
# 0022100080
# 0022100081
# 0022100082
# 0022100083
# 0022100084
# 0022100085
# 0022100086
# 0022100087
# 0022100088
# 0022100089
# 0022100090
# 0022100091
# 0022100092
# 0022100093
# 0022100094
# 0022100095
# 0022100096
# 0022100097
# 0022100098
# 0022100099
# 0022100100
# 0022100101
# 0022100102
# 0022100103
# 0022100104
# 0022100105
# 0022100106
# 0022100108
# 0022100109
# 0022100110
# 0022100111
# 0022100112
# 0022100113
# 0022100114
# 0022100115
# 0022100116
# 0022100117
# 0022100118
# 0022100119
# 0022100120
# 0022100121
# 0022100122
# 0022100123
# 0022100124
# 0022100125
# 0022100126
# 0022100127
# 0022100128
# 0022100129
# 0022100130
# 0022100131
# 0022100132
# 0022100133
# 0022100134
# 0022100135
# 0022100136
# 0022100137
# 0022100138
# 0022100139
# 0022100140
# 0022100141
# 0022100142
# 197
# GAME_ID                                            22100142
# EVENTNUM                                                292
# EVENTMSGTYPE                                              3
# EVENTMSGACTIONTYPE                                       16
# PERIOD                                                    2
# WCTIMESTRING                                        7:03 PM
# PCTIMESTRING                                           2:44
# HOMEDESCRIPTION              MISS Beal Free Throw Technical
# NEUTRALDESCRIPTION           MISS Beal Free Throw Technical
# VISITORDESCRIPTION
# SCORE                                                   NaN
# SCOREMARGIN                                             NaN
# PERSON1TYPE                                               4
# PLAYER1_ID                                           203078
# PLAYER1_NAME                                   Bradley Beal
# PLAYER1_TEAM_ID                                1610612764.0
# PLAYER1_TEAM_CITY                                Washington
# PLAYER1_TEAM_NICKNAME                               Wizards
# PLAYER1_TEAM_ABBREVIATION                               WAS
# PERSON2TYPE                                               0
# PLAYER2_ID                                                0
# PLAYER2_NAME                                            NaN
# PLAYER2_TEAM_ID                                         NaN
# PLAYER2_TEAM_CITY                                       NaN
# PLAYER2_TEAM_NICKNAME                                   NaN
# PLAYER2_TEAM_ABBREVIATION                               NaN
# PERSON3TYPE                                               0
# PLAYER3_ID                                                0
# PLAYER3_NAME                                            NaN
# PLAYER3_TEAM_ID                                         NaN
# PLAYER3_TEAM_CITY                                       NaN
# PLAYER3_TEAM_NICKNAME                                   NaN
# PLAYER3_TEAM_ABBREVIATION                               NaN
# VIDEO_AVAILABLE_FLAG                                      1
# TIME_ELAPSED                                           1276
# TIME_ELAPSED_PERIOD                                     556
# TEAM1_ID                                         1610612749
# TEAM1_PLAYER1                                       1626192
# TEAM1_PLAYER2                                       1628400
# TEAM1_PLAYER3                                       1628960
# TEAM1_PLAYER4                                        201588
# TEAM1_PLAYER5                                        201950
# TEAM2_ID                                         1610612764
# TEAM2_PLAYER1                                       1628398
# TEAM2_PLAYER2                                       1629655
# TEAM2_PLAYER3                                       1630557
# TEAM2_PLAYER4                                        203078
# TEAM2_PLAYER5                                        203526
# Name: 197, dtype: object
# 0022100143
# 0022100144
# 0022100145
# 0022100146
# 0022100147
# 0022100148
# 0022100149
# 0022100150
# 0022100151
# 0022100152
# 0022100153
# 0022100154
# 0022100155
# 0022100156
# 0022100157
# 0022100159
# 0022100160
# 0022100161
# 0022100162
# 0022100163
# 0022100164
# 0022100165
# 0022100166
# 0022100167
# 0022100168
# 0022100169
# 0022100170
# 0022100171
# 0022100172
# 0022100173
# 0022100174
# 0022100175
# 0022100176
# 0022100177
# 0022100178
# 0022100179
# 0022100180
# 0022100181
# 0022100183
# 0022100184
# 0022100185
# 0022100186
# 0022100187
# 0022100188
# 0022100189
# 0022100190
# 0022100191
# 0022100192
# 0022100193
# 0022100194
# 0022100195
# 0022100196
# 0022100197
# 0022100198
# 0022100199
# 0022100200
# 0022100201
# 0022100202
# 0022100203
# 0022100204
# 0022100205
# 0022100206
# 0022100207
# 0022100208
# 0022100209
# 0022100210
# 0022100211
# 0022100212
# 0022100213
# 0022100214
# 0022100215
# 0022100216
# 0022100217
# 0022100218
# 0022100219
# 0022100220
# 0022100221
# 0022100222
# 0022100223
# 0022100224
# 0022100226
# 0022100227
# 0022100228
# 0022100229
# 0022100230
# 0022100231
# 0022100232
# 0022100233
# 0022100234
# 0022100235
# 0022100236
# 0022100237
# 0022100238
# 0022100240
# 0022100241
# 0022100242
# 0022100243
# 0022100244
# 0022100245
# 0022100246
# 0022100247
# 0022100248
# 0022100249
# 0022100250
# 0022100252
# 0022100253
# 0022100254
# 0022100255
# 0022100256
# 0022100257
# 0022100258
# 0022100259
# 0022100260
# 0022100261
# 0022100262
# 0022100263
# 0022100264
# 0022100265
# 0022100266
# 0022100267
